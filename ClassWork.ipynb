# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gyms = ["Crunch", "Planet Fitness", "NY Sports Club", "Rickie's Gym"]
members=[49,92,84,55]

# %%
plt.bar(gyms, members)
# Out:
# <BarContainer object of 4 artists>

# %%
cost = [1,2,3,4,5,6,7,8,9]
speed =[49, 92, 84, 55, 33, 44, 55, 44, 33]

# %%
plt.plot(cost, speed)

# %%
mpg = [1,2,3,4,5,6,7,8,9]
horsepower =[49, 92, 84, 55, 33, 44, 55, 44, 33]

plt.title("Roller Coaster Speed Over Time")
plt.xlabel("Speed (mph)")
plt.ylabel("Time (secs)")

plt.scatter(mpg, horsepower, marker="o", color = "green")

# %%
cyl = [8,8,8,8,8,4,4,4,4]
cyl_adj = (item * 10 for item in cyl)
plt.xlim(0, 250)
plt.ylim(5, 35)
plt.scatter(horsepower, mpg, marker="o", facecolors ='red', edgecolors='black',  label = "#of Cyl") #s=cyl_adj,
plt.legend()

# %%
#Read ave rain state - comma separated
#State Inches, Millimentres Rank
#.head()

# %%
#x_axis = np.arange(len(dain_df))
tick_locations = [value for value in x_axis] #copy of x_axis
plt.figure(figzise =(20,3))
plt.bar(x_axis, rani_df['Inches', color='r', alpha=0.5, align='center'])  #hard to read

# %%
#re-wite
plt.xlim(0.75, len(x_axis))
pg.ylim(0, max(rain_df['Inches']) + 10)
plt. title
plt.xlim()
plt.ylim()

# %%
plt.tigh_layout() #make all arranged, readable
plt.savefig('../image/rain.png')
plt.show()

# %%
#extract DF down
state_and_inches = rain_df[['State', 'Rain(Inches)']] #outer is call DB, [ inner is calling columns]
state_and_inches.set_index('state')
state_and_inches.plot(kind='bar', figsize(20,3))
plt.titiel('Average Rain Fall')
plt.xticks()
plt.yticks()
plt.show()
plt.tight_layout()

# %%
attacks = df[].value_count
defenses = df[].value_count

# %%
battles = attacks.add(defenses, fill_value = 0) #series, fill_value replaces NaN
bottls.plot(kind='bar', rot=45, tiltle = 'bottle', xlabel ='Kings' ylagel ='Number of bottles') #rot = rotate
plt.xticks(45) #rotate
plt.tight_layout()

# %%
#Bike Trippin
# low_memory dtype warning - one of the dtype isn't expected trips['birth_year'].value_count() or 
#groupby gender
gender_tirps = gender_group[tripduration] .count(0)
#type(gender_trips) will show series or data frame.
X -> gentder Y _> trip count
#clean_trip.
